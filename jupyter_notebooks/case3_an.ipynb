# %% [markdown]
# # Case3_an

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case3_an import *
case = Case3_an("dot_atlas/case3_an.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# b, parents=['n', 'a'], children=['s']
# ['n', 'a', 'b']
# [[[0.81814054 0.18185946]
#   [0.06747563 0.93252437]
#   [0.85403525 0.14596475]]
#
#  [[0.99666707 0.00333293]
#   [0.70959969 0.29040031]
#   [0.42124911 0.57875089]]]
#
# a, parents=['n'], children=['b', 's']
# ['n', 'a']
# [[0.20318662 0.05854966 0.73826372]
#  [0.14632851 0.29566123 0.55801027]]
#
# n, parents=[], children=['b', 'a', 's']
# ['n']
# [0.92598318 0.07401682]
#
# s, parents=['b', 'n', 'a'], children=[]
# ['b', 'n', 'a', 's']
# [[[[0.68233733 0.31766267]
#    [0.26425843 0.73574157]
#    [0.07185194 0.92814806]]
#
#   [[0.61718488 0.38281512]
#    [0.59818605 0.40181395]
#    [0.60759379 0.39240621]]]
#
#
#  [[[0.79940845 0.20059155]
#    [0.24976996 0.75023004]
#    [0.54693487 0.45306513]]
#
#   [[0.5666914  0.4333086 ]
#    [0.6868013  0.3131987 ]
#    [0.24184193 0.75815807]]]]
#
#
# ...
