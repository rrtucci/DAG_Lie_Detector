# %% [markdown]
# # Case 1

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case1 import *
case = Case1("dot_atlas/case1.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# a, parents=[], children=['z', 'b']
# ['a']
# [0.36248645 0.31423206 0.32328149]
#
# z, parents=['a', 'b'], children=[]
# ['a', 'b', 'z']
# [[[0.11623946 0.88376054]
#   [0.51706011 0.48293989]]
#
#  [[0.83438739 0.16561261]
#   [0.40078457 0.59921543]]
#
#  [[0.66533722 0.33466278]
#   [0.3366034  0.6633966 ]]]
#
# b, parents=['a'], children=['z']
# ['a', 'b']
# [[0.65859132 0.34140868]
#  [0.36773129 0.63226871]
#  [0.79145637 0.20854363]]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# a->z;
# b->z
# }
# DAGs for which GCF will be calculated (non-maximal generation of G_pd)
#
# name: G_1
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('b', 'z'),
#
# name: G_2
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('b', 'z'),
# link to heights:
# link , height_0 , height_1
# ('a', 'b') 	 0.06723 	 0.00000
#
# GCF for each dag:
# ...
