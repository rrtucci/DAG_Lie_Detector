# %% [markdown]
# # Case 1

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case1 import *
case = Case1()
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# a, parents=[], children=['b', 'z']
# ['a']
# [0.405446   0.2108415  0.38371249]
#
# b, parents=['a'], children=['z']
# ['a', 'b']
# [[0.39623562 0.60376438]
#  [0.46535343 0.53464657]
#  [0.28091717 0.71908283]]
#
# z, parents=['a', 'b'], children=[]
# ['a', 'b', 'z']
# [[[0.39091765 0.60908235]
#   [0.49060189 0.50939811]]
#
#  [[0.57973887 0.42026113]
#   [0.74123603 0.25876397]]
#
#  [[0.55195599 0.44804401]
#   [0.68174439 0.31825561]]]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# a->z;
# b->z
# }
# DAGs for which GCF will be calculated (non-maximal generation of G_pd)
#
# name: G_1
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('b', 'z'),
#
# name: G_2
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('b', 'z'),
# link to heights:
# link , height_0 , height_1
# ('a', 'b') 	 0.01156 	 -0.00000
#
# GCF for each dag:
# ...
