# %% [markdown]
# # Case1_2_Haz

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case1_2_Haz import *
case = Case1_2_Haz("dot_atlas/case1_2.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# b, parents=['a'], children=['z']
# ['a', 'b']
# [[0.38712504 0.61287496]
#  [0.05272611 0.94727389]
#  [0.59031209 0.40968791]]
#
# z, parents=['b', 'a', 'H'], children=[]
# ['b', 'a', 'H', 'z']
# [[[[0.80283504 0.19716496]
#    [0.77756319 0.22243681]]
#
#   [[0.50154572 0.49845428]
#    [0.70967381 0.29032619]]
#
#   [[0.51835496 0.48164504]
#    [0.11444176 0.88555824]]]
#
#
#  [[[0.82147998 0.17852002]
#    [0.4491127  0.5508873 ]]
#
#   [[0.38586659 0.61413341]
#    [0.19280074 0.80719926]]
#
#   [[0.72766932 0.27233068]
#    [0.34392121 0.65607879]]]]
#
# a, parents=['H'], children=['z', 'b']
# ['H', 'a']
# [[0.07506869 0.57073992 0.35419139]
#  [0.32523309 0.30472781 0.37003909]]
#
# H, parents=[], children=['a', 'z']
# ['H']
# [0.7471664 0.2528336]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# a->z;
# ...
