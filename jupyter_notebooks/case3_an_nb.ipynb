# %% [markdown]
# # Case3_an_nb

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case3_an_nb import *
case = Case3_an_nb("dot_atlas/case3_an_nb.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# n, parents=[], children=['b', 'a', 's']
# ['n']
# [0.3881309 0.6118691]
#
# b, parents=['n', 'a'], children=['s']
# ['n', 'a', 'b']
# [[[0.73204531 0.26795469]
#   [0.3612692  0.6387308 ]
#   [0.68817122 0.31182878]]
#
#  [[0.664177   0.335823  ]
#   [0.60034052 0.39965948]
#   [0.75991929 0.24008071]]]
#
# a, parents=['n'], children=['b', 's']
# ['n', 'a']
# [[0.16701066 0.58409559 0.24889375]
#  [0.03043734 0.83088219 0.13868047]]
#
# s, parents=['n', 'b', 'a'], children=[]
# ['n', 'b', 'a', 's']
# [[[[0.10701718 0.89298282]
#    [0.92330197 0.07669803]
#    [0.81424555 0.18575445]]
#
#   [[0.52821148 0.47178852]
#    [0.42177562 0.57822438]
#    [0.13457553 0.86542447]]]
#
#
#  [[[0.98546675 0.01453325]
#    [0.53693753 0.46306247]
#    [0.95796489 0.04203511]]
#
#   [[0.47721669 0.52278331]
#    [0.85118323 0.14881677]
#    [0.4342143  0.5657857 ]]]]
#
#
# ...
