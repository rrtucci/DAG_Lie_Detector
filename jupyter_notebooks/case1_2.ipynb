# %% [markdown]
# # Case1_2

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case1_2 import *
case = Case1_2("dot_atlas/case1_2.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# b, parents=['a'], children=['z']
# ['a', 'b']
# [[0.44880273 0.55119727]
#  [0.40928162 0.59071838]
#  [0.02264762 0.97735238]]
#
# a, parents=[], children=['b', 'z']
# ['a']
# [0.15974793 0.71494737 0.1253047 ]
#
# z, parents=['b', 'a'], children=[]
# ['b', 'a', 'z']
# [[[0.67823737 0.32176263]
#   [0.31850224 0.68149776]
#   [0.6896788  0.3103212 ]]
#
#  [[0.15776011 0.84223989]
#   [0.72766652 0.27233348]
#   [0.40886158 0.59113842]]]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# a->z;
# b->z [arrowhead=none,color=red];
# }
# DAGs for which GCF will be calculated (non-maximal generation of G_pd)
#
# name: G_1
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('b', 'z'),
#
# name: G_2
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('z', 'b'),
#
# name: G_3
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('b', 'z'),
#
# ...
