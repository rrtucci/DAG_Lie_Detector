# %% [markdown]
# # Case1_2_Haz

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case1_2_Haz import *
case = Case1_2_Haz("dot_atlas/case1_2.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# a, parents=['H'], children=['b', 'z']
# ['H', 'a']
# [[0.2256211  0.54709918 0.22727971]
#  [0.73232791 0.01559165 0.25208043]]
#
# z, parents=['a', 'H', 'b'], children=[]
# ['a', 'H', 'b', 'z']
# [[[[0.77090108 0.22909892]
#    [0.51066375 0.48933625]]
#
#   [[0.34633598 0.65366402]
#    [0.53266967 0.46733033]]]
#
#
#  [[[0.16098867 0.83901133]
#    [0.65490931 0.34509069]]
#
#   [[0.94712962 0.05287038]
#    [0.68332258 0.31667742]]]
#
#
#  [[[0.61751192 0.38248808]
#    [0.73245327 0.26754673]]
#
#   [[0.6584425  0.3415575 ]
#    [0.60366169 0.39633831]]]]
#
# H, parents=[], children=['a', 'z']
# ['H']
# [0.14268157 0.85731843]
#
# b, parents=['a'], children=['z']
# ['a', 'b']
# [[0.17370797 0.82629203]
#  [0.44457119 0.55542881]
#  [0.26789148 0.73210852]]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# a->z;
# b->z [arrowhead=none,color=red];
# }
# DAGs for which GCF will be calculated (non-maximal generation of G_pd)
#
# name: G_1
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('b', 'z'),
#
# name: G_2
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('z', 'b'),
#
# name: G_3
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('b', 'z'),
#
# name: G_4
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('z', 'b'),
# link to heights:
# link , height_0 , height_1
# ('a', 'b') 	 0.01628 	 -0.00000
# link , height_0 , height_1
# ('b', 'z') 	 0.00641 	 0.00000
#
# GCF for each dag:
# dag= G_1 ,	GCF= 1.00000
# dag= G_2 ,	GCF= 0.43506
# dag= G_3 ,	GCF= -0.43506
# dag= G_4 ,	GCF= -1.00000
