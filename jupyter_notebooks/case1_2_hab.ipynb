# %% [markdown]
# # Case1_2_Hab

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case1_2_Hab import *
case = Case1_2_Hab("dot_atlas/case1_2.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# a, parents=['H'], children=['z', 'b']
# ['H', 'a']
# [[0.35488399 0.29472633 0.35038968]
#  [0.55765226 0.25931664 0.1830311 ]]
#
# z, parents=['a', 'b'], children=[]
# ['a', 'b', 'z']
# [[[0.91067569 0.08932431]
#   [0.72172405 0.27827595]]
#
#  [[0.2224064  0.7775936 ]
#   [0.49660728 0.50339272]]
#
#  [[0.09182226 0.90817774]
#   [0.52449467 0.47550533]]]
#
# H, parents=[], children=['a', 'b']
# ['H']
# [0.7580308 0.2419692]
#
# b, parents=['a', 'H'], children=['z']
# ['a', 'H', 'b']
# [[[0.44727746 0.55272254]
#   [0.18831625 0.81168375]]
#
#  [[0.97821629 0.02178371]
#   [0.51433605 0.48566395]]
#
#  [[0.58219534 0.41780466]
#   [0.49055812 0.50944188]]]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# a->z;
# b->z [arrowhead=none,color=red];
# }
# DAGs for which GCF will be calculated (non-maximal generation of G_pd)
#
# name: G_1
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('b', 'z'),
#
# name: G_2
# nodes: a, b, z,
# arrows: ('a', 'b'), ('a', 'z'), ('z', 'b'),
#
# name: G_3
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('b', 'z'),
#
# name: G_4
# nodes: b, a, z,
# arrows: ('b', 'a'), ('a', 'z'), ('z', 'b'),
# link to heights:
# link , height_0 , height_1
# ('a', 'b') 	 0.10322 	 -0.00000
# link , height_0 , height_1
# ('b', 'z') 	 0.01240 	 0.00000
#
# GCF for each dag:
# dag= G_1 ,	GCF= 1.00000
# dag= G_2 ,	GCF= 0.78554
# dag= G_3 ,	GCF= -0.78554
# dag= G_4 ,	GCF= -1.00000
