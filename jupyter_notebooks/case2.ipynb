# %% [markdown]
# # Case2

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case2 import *
case = Case2()
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# d, parents=['c', 'a'], children=['e']
# ['c', 'a', 'd']
# [[[0.75879778 0.24120222]
#   [0.50060224 0.49939776]
#   [0.63658104 0.36341896]]
#
#  [[0.39138645 0.60861355]
#   [0.3208983  0.6791017 ]
#   [0.42431429 0.57568571]]]
#
# b, parents=['a'], children=['c']
# ['a', 'b']
# [[0.45349019 0.54650981]
#  [0.83298745 0.16701255]
#  [0.54001245 0.45998755]]
#
# a, parents=[], children=['d', 'b']
# ['a']
# [0.4568198  0.46818966 0.07499054]
#
# e, parents=['d'], children=[]
# ['d', 'e']
# [[0.05521637 0.94478363]
#  [0.40109455 0.59890545]]
#
# c, parents=['b'], children=['d']
# ['b', 'c']
# [[0.66288163 0.33711837]
#  [0.33850607 0.66149393]]
#
#
# Partially Directed graph G_pd:
# digraph G {
# a->b [arrowhead=none,color=red];
# b->c [arrowhead=none,color=red];
# a->d;
# c->d;
# d->e
# }
# DAGs for which GCF will be calculated (non-maximal generation of G_pd)
#
# name: G_1
# ...
