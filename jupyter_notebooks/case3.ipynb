# %% [markdown]
# # Case3

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case3 import *
case = Case3("dot_atlas/case3.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# a, parents=['n'], children=['b', 's']
# ['n', 'a']
# [[0.23908112 0.11986926 0.64104962]
#  [0.25735615 0.38104089 0.36160297]]
#
# n, parents=[], children=['a', 'b', 's']
# ['n']
# [0.34974624 0.65025376]
#
# b, parents=['a', 'n'], children=['s']
# ['a', 'n', 'b']
# [[[0.91651274 0.08348726]
#   [0.04135177 0.95864823]]
#
#  [[0.29031598 0.70968402]
#   [0.5883233  0.4116767 ]]
#
#  [[0.27615745 0.72384255]
#   [0.32810679 0.67189321]]]
#
# s, parents=['a', 'n', 'b'], children=[]
# ['a', 'n', 'b', 's']
# [[[[0.07188441 0.92811559]
#    [0.63991101 0.36008899]]
#
#   [[0.25884566 0.74115434]
#    [0.924968   0.075032  ]]]
#
#
#  [[[0.79219637 0.20780363]
#    [0.50693721 0.49306279]]
#
#   [[0.07383659 0.92616341]
#    [0.74574053 0.25425947]]]
#
#
#  [[[0.6701729  0.3298271 ]
#    [0.72277894 0.27722106]]
#
#   [[0.50580426 0.49419574]
#    [0.49941855 0.50058145]]]]
#
#
# ...
