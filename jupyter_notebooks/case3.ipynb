# %% [markdown]
# # Case3

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case3 import *
case = Case3("dot_atlas/case3.dot")
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# n, parents=[], children=['b', 's', 'a']
# ['n']
# [0.99604979 0.00395021]
#
# b, parents=['n', 'a'], children=['s']
# ['n', 'a', 'b']
# [[[0.11066006 0.88933994]
#   [0.58057567 0.41942433]
#   [0.71707691 0.28292309]]
#
#  [[0.06276945 0.93723055]
#   [0.53727293 0.46272707]
#   [0.99447629 0.00552371]]]
#
# s, parents=['n', 'b', 'a'], children=[]
# ['n', 'b', 'a', 's']
# [[[[0.16976684 0.83023316]
#    [0.35375625 0.64624375]
#    [0.43926888 0.56073112]]
#
#   [[0.59388751 0.40611249]
#    [0.5502038  0.4497962 ]
#    [0.29722607 0.70277393]]]
#
#
#  [[[0.59530334 0.40469666]
#    [0.50658769 0.49341231]
#    [0.42678212 0.57321788]]
#
#   [[0.94496457 0.05503543]
#    [0.11744772 0.88255228]
#    [0.71711789 0.28288211]]]]
#
# a, parents=['n'], children=['s', 'b']
# ['n', 'a']
# [[0.78959224 0.14397517 0.06643259]
#  [0.45938669 0.46094911 0.07966421]]
#
#
# ...
