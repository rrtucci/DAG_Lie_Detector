# %% [markdown]
# # Case3

# %%
import os
import sys
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
sys.path.insert(0,os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector\jupyter_notebooks
# C:\Users\rrtuc\Desktop\backed-up\python-projects\DAG_Lie_Detector

# %%
from Case3 import *
case = Case3()
case.run(jupyter=True, draw=True)
# Out:
# We are choosing a truth bnet with the same structure as G_1
# Truth bnet (used to simulate empirical probs):
# a, parents=['n'], children=['s', 'b']
# ['n', 'a']
# [[0.29063063 0.2908718  0.41849758]
#  [0.13265946 0.61337162 0.25396892]]
#
# s, parents=['a', 'n', 'b'], children=[]
# ['a', 'n', 'b', 's']
# [[[[0.71552538 0.28447462]
#    [0.42628836 0.57371164]]
#
#   [[0.31878701 0.68121299]
#    [0.58960483 0.41039517]]]
#
#
#  [[[0.71609984 0.28390016]
#    [0.24602709 0.75397291]]
#
#   [[0.54241041 0.45758959]
#    [0.73666449 0.26333551]]]
#
#
#  [[[0.69339964 0.30660036]
#    [0.87975138 0.12024862]]
#
#   [[0.70659692 0.29340308]
#    [0.43652791 0.56347209]]]]
#
# n, parents=[], children=['s', 'b', 'a']
# ['n']
# [0.38359571 0.61640429]
#
# b, parents=['a', 'n'], children=['s']
# ['a', 'n', 'b']
# [[[0.51183969 0.48816031]
#   [0.34775782 0.65224218]]
#
#  [[0.33446082 0.66553918]
#   [0.74713952 0.25286048]]
#
#  [[0.66052826 0.33947174]
#   [0.45481819 0.54518181]]]
#
#
# ...
